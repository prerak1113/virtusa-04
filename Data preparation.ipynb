# %%
import pandas as pd
import numpy as np
import random

# %%
primary_list=[]
secondary_list=[]
Primary = ['Premera Blue Cross Blue Shield of Alaska','Moda Health','Bright HealthCare','Blue Cross and Blue Shield of Alabama','Alliant Health Plans','Ambetter from Arizona Complete Health','Ambetter from Buckeye Health','Aspirus Health Plan','AvMed','BlueCross BlueShield of Tennessee','Cox HealthPlans','FirstCare Health Plans','Cigna Healthcare','Highmark Blue Cross Blue Shield West Virginia','Medicare','Sanford Health Plan','Florida Health Care Plans','MercyCare Health Plans','Vantage Health Plan','Health First Commercial Plans, Inc.','Quartz','Paramount','McLaren Health Plan Community','QC Life and Health','Dean Health Plan']
Secondary = ['Medicaid','Ambetter from Buckeye Health','Aspirus Health Plan','AvMed','BlueCross BlueShield of Tennessee','Cox HealthPlans','FirstCare Health Plans','Cigna Healthcare','Highmark Blue Cross Blue Shield West Virginia','Medicare','Sanford Health Plan','Florida Health Care Plans','MercyCare Health Plans','Vantage Health Plan','Health First Commercial Plans, Inc.','Quartz','Paramount','McLaren Health Plan Community','QC Life and Health','Dean Health Plan']
for i in range(0,10000):
    random_policy = random.choice(Primary)
    random_policy1 = random.choice(Secondary)
    if (random_policy!=random_policy1):
        primary_list.append(random_policy)
        secondary_list.append(random_policy1)
    else:
        random_policy = random.choice(Primary)
        random_policy1 = random.choice(Secondary)
        primary_list.append(random_policy)
        secondary_list.append(random_policy1)

# %%
plan_type_list=[]
plan_type = ["HMO","PPO","EPO","POS"]
for i in range(0,len(primary_list)):
    random_policy = random.choice(plan_type)
    plan_type_list.append(random_policy)

# %%
ctype=[]
types = ["Hospital Inpatient Claims","Long Term Care Claims","Medicare Part A Claims", "Medicare Part B Claims", "Out Patient Claims","Professional Service Claims","RHC, FQHC, IHC Claims"]
for i in range(0,len(primary_list)):
    random_claim = random.choice(types)
    ctype.append(random_claim)

# %%
copay=np.random.randint(100,500,10000)

# %%
coins=[]
coins_list =[0,20,25,30,35,40,45,50]
for i in range(0,len(primary_list)):
    random_coins = random.choice(coins_list)
    coins.append(random_coins)

# %%
deduc = list(np.random.randint(30,70,10000))

# %%
billed_amt = list(np.random.randint(4000,6000,10000))

# %%
allowed_amt = list(np.random.randint(1000,3000,10000))

# %%
Secondary_allowed_amt = list(np.random.randint(500,4000,10000))

# %%
Claim_ID = list(np.random.randint(1000000000,2000000000,10000))

# %%
len(coins)
# Out:
# 10000

# %%
data1 = pd.DataFrame({"Claim ID":Claim_ID,"Primary":primary_list,"Secondary":secondary_list,"Claim Type":ctype,"Plan_Type":plan_type_list,"Billed_Amt":billed_amt,"P_Allowed_Amt":allowed_amt,"Deductible":deduc,"CoInsurance":coins,"Copay":copay,"S_Allowed_Amt":Secondary_allowed_amt})

# %%
data1
# Out:
#         Claim ID                              Primary  \
# 0     1109820231                     Dean Health Plan
# 1     1031142215                  Vantage Health Plan
# 2     1811391063                               Quartz
# 3     1510918907         Ambetter from Buckeye Health
# 4     1679947328                  Aspirus Health Plan
# ...          ...                                  ...
# 9995  1360332344         Ambetter from Buckeye Health
# 9996  1435232368                               Quartz
# 9997  1455330290  Health First Commercial Plans, Inc.
# 9998  1770493708                    Bright HealthCare
# 9999  1839120188               FirstCare Health Plans
#
#                                           Secondary  \
# 0                      Ambetter from Buckeye Health
# 1     Highmark Blue Cross Blue Shield West Virginia
# 2                      Ambetter from Buckeye Health
# 3                                             AvMed
# ...

# %%
data1["CoInsurance_Amt"] = (data1["P_Allowed_Amt"]*data1["CoInsurance"])/100

# %%
data1
# Out:
#         Claim ID                              Primary  \
# 0     1109820231                     Dean Health Plan
# 1     1031142215                  Vantage Health Plan
# 2     1811391063                               Quartz
# 3     1510918907         Ambetter from Buckeye Health
# 4     1679947328                  Aspirus Health Plan
# ...          ...                                  ...
# 9995  1360332344         Ambetter from Buckeye Health
# 9996  1435232368                               Quartz
# 9997  1455330290  Health First Commercial Plans, Inc.
# 9998  1770493708                    Bright HealthCare
# 9999  1839120188               FirstCare Health Plans
#
#                                           Secondary  \
# 0                      Ambetter from Buckeye Health
# 1     Highmark Blue Cross Blue Shield West Virginia
# 2                      Ambetter from Buckeye Health
# 3                                             AvMed
# ...

# %%
data1["Primary_paid"] = data1["P_Allowed_Amt"] - data1["CoInsurance_Amt"] - data1["Deductible"] - data1["Copay"]

# %%
data1
# Out:
#         Claim ID                              Primary  \
# 0     1109820231                     Dean Health Plan
# 1     1031142215                  Vantage Health Plan
# 2     1811391063                               Quartz
# 3     1510918907         Ambetter from Buckeye Health
# 4     1679947328                  Aspirus Health Plan
# ...          ...                                  ...
# 9995  1360332344         Ambetter from Buckeye Health
# 9996  1435232368                               Quartz
# 9997  1455330290  Health First Commercial Plans, Inc.
# 9998  1770493708                    Bright HealthCare
# 9999  1839120188               FirstCare Health Plans
#
#                                           Secondary  \
# 0                      Ambetter from Buckeye Health
# 1     Highmark Blue Cross Blue Shield West Virginia
# 2                      Ambetter from Buckeye Health
# 3                                             AvMed
# ...

# %%
data1
# Out:
#         Claim ID                              Primary  \
# 0     1109820231                     Dean Health Plan
# 1     1031142215                  Vantage Health Plan
# 2     1811391063                               Quartz
# 3     1510918907         Ambetter from Buckeye Health
# 4     1679947328                  Aspirus Health Plan
# ...          ...                                  ...
# 9995  1360332344         Ambetter from Buckeye Health
# 9996  1435232368                               Quartz
# 9997  1455330290  Health First Commercial Plans, Inc.
# 9998  1770493708                    Bright HealthCare
# 9999  1839120188               FirstCare Health Plans
#
#                                           Secondary  \
# 0                      Ambetter from Buckeye Health
# 1     Highmark Blue Cross Blue Shield West Virginia
# 2                      Ambetter from Buckeye Health
# 3                                             AvMed
# ...

# %%
data1
# Out:
#         Claim ID                              Primary  \
# 0     1109820231                     Dean Health Plan
# 1     1031142215                  Vantage Health Plan
# 2     1811391063                               Quartz
# 3     1510918907         Ambetter from Buckeye Health
# 4     1679947328                  Aspirus Health Plan
# ...          ...                                  ...
# 9995  1360332344         Ambetter from Buckeye Health
# 9996  1435232368                               Quartz
# 9997  1455330290  Health First Commercial Plans, Inc.
# 9998  1770493708                    Bright HealthCare
# 9999  1839120188               FirstCare Health Plans
#
#                                           Secondary  \
# 0                      Ambetter from Buckeye Health
# 1     Highmark Blue Cross Blue Shield West Virginia
# 2                      Ambetter from Buckeye Health
# 3                                             AvMed
# ...

# %%
data1["Secondary_paid"]=0

# %%
data1
# Out:
#         Claim ID                              Primary  \
# 0     1109820231                     Dean Health Plan
# 1     1031142215                  Vantage Health Plan
# 2     1811391063                               Quartz
# 3     1510918907         Ambetter from Buckeye Health
# 4     1679947328                  Aspirus Health Plan
# ...          ...                                  ...
# 9995  1360332344         Ambetter from Buckeye Health
# 9996  1435232368                               Quartz
# 9997  1455330290  Health First Commercial Plans, Inc.
# 9998  1770493708                    Bright HealthCare
# 9999  1839120188               FirstCare Health Plans
#
#                                           Secondary  \
# 0                      Ambetter from Buckeye Health
# 1     Highmark Blue Cross Blue Shield West Virginia
# 2                      Ambetter from Buckeye Health
# 3                                             AvMed
# ...

# %%
data1
# Out:
#         Claim ID                              Primary  \
# 0     1109820231                     Dean Health Plan
# 1     1031142215                  Vantage Health Plan
# 2     1811391063                               Quartz
# 3     1510918907         Ambetter from Buckeye Health
# 4     1679947328                  Aspirus Health Plan
# ...          ...                                  ...
# 9995  1360332344         Ambetter from Buckeye Health
# 9996  1435232368                               Quartz
# 9997  1455330290  Health First Commercial Plans, Inc.
# 9998  1770493708                    Bright HealthCare
# 9999  1839120188               FirstCare Health Plans
#
#                                           Secondary  \
# 0                      Ambetter from Buckeye Health
# 1     Highmark Blue Cross Blue Shield West Virginia
# 2                      Ambetter from Buckeye Health
# 3                                             AvMed
# ...

# %%
data1["OOP"] = data1["Billed_Amt"]-data1["Primary_paid"]-data1["Secondary_paid"]

# %%
data1
# Out:
#         Claim ID                              Primary  \
# 0     1109820231                     Dean Health Plan
# 1     1031142215                  Vantage Health Plan
# 2     1811391063                               Quartz
# 3     1510918907         Ambetter from Buckeye Health
# 4     1679947328                  Aspirus Health Plan
# ...          ...                                  ...
# 9995  1360332344         Ambetter from Buckeye Health
# 9996  1435232368                               Quartz
# 9997  1455330290  Health First Commercial Plans, Inc.
# 9998  1770493708                    Bright HealthCare
# 9999  1839120188               FirstCare Health Plans
#
#                                           Secondary  \
# 0                      Ambetter from Buckeye Health
# 1     Highmark Blue Cross Blue Shield West Virginia
# 2                      Ambetter from Buckeye Health
# 3                                             AvMed
# ...

# %%
data1
# Out:
#         Claim ID                              Primary  \
# 0     1109820231                     Dean Health Plan
# 1     1031142215                  Vantage Health Plan
# 2     1811391063                               Quartz
# 3     1510918907         Ambetter from Buckeye Health
# 4     1679947328                  Aspirus Health Plan
# ...          ...                                  ...
# 9995  1360332344         Ambetter from Buckeye Health
# 9996  1435232368                               Quartz
# 9997  1455330290  Health First Commercial Plans, Inc.
# 9998  1770493708                    Bright HealthCare
# 9999  1839120188               FirstCare Health Plans
#
#                                           Secondary  \
# 0                      Ambetter from Buckeye Health
# 1     Highmark Blue Cross Blue Shield West Virginia
# 2                      Ambetter from Buckeye Health
# 3                                             AvMed
# ...

# %%
data1.head(4)
# Out:
#      Claim ID                       Primary  \
# 0  1109820231              Dean Health Plan
# 1  1031142215           Vantage Health Plan
# 2  1811391063                        Quartz
# 3  1510918907  Ambetter from Buckeye Health
#
#                                        Secondary                   Claim Type  \
# 0                   Ambetter from Buckeye Health       Medicare Part A Claims
# 1  Highmark Blue Cross Blue Shield West Virginia  Professional Service Claims
# 2                   Ambetter from Buckeye Health        Long Term Care Claims
# 3                                          AvMed    Hospital Inpatient Claims
#
#   Plan_Type  Billed_Amt  P_Allowed_Amt  Deductible  CoInsurance  Copay  \
# 0       PPO        4101           2429          36           25    261
# 1       EPO        4812           1336          62            0    198
# 2       EPO        4077           2404          30           50    269
# ...

# %%
Claim_types = ["Hospital Inpatient Claims","Long Term Care Claims","Medicare Part A Claims", "Medicare Part B Claims", "Out Patient Claims","Professional Service Claims","RHC, FQHC, IHC Claims"]

# %%
if (data1["Claim Type"][i] =="Hospital Inpatient Claims" or data1["Claim Type"][i] =="Medicare Part A Claims"):
    # Member Responsibility
    for i in range(0,len(Secondary_allowed_amt)):
        if(data1["S_Allowed_Amt"][i]>data1["Primary_paid"][i]):
            if(data1["S_Allowed_Amt"][i]>=data1["CoInsurance_Amt"][i]+data1["Copay"][i]+data1["Deductible"][i]):
                data1["Secondary_paid"][i] = data1["CoInsurance_Amt"][i]+data1["Copay"][i]+data1["Deductible"][i]
            else:
                data1["Secondary_paid"][i] = data1["S_Allowed_Amt"][i]
        else:
            data1["Secondary_paid"][i] = 0
elif (data1["Claim Type"][i] == "Medicare Part B Claims" or data1["Claim Type"][i] == "Out Patient Claims" or data1["Claim Type"][i] == "Professional Service Claims"):
    # Lesser of
    for i in range(0,len(Secondary_allowed_amt)):
        if(data1["S_Allowed_Amt"][i]>data1["Primary_paid"][i]):
                data1["Secondary_paid"][i] = data1["S_Allowed_Amt"][i] - data1["Primary_paid"][i]
        else:
            data1["Secondary_paid"][i] = 0
        if(data1["S_Allowed_Amt"][i]>data1["P_Allowed_Amt"][i]):
            data1["Secondary_paid"][i] = data1["Secondary_paid"][i] - (data1["S_Allowed_Amt"][i]- data1["P_Allowed_Amt"][i])
    data1["OOP"] = data1["Billed_Amt"]-data1["Primary_paid"]-data1["Secondary_paid"]
elif (data1["Claim Type"][i] =="Long Term Care Claims" or data1["Claim Type"][i] == "RHC, FQHC, IHC Claims"):
    #Allowed Amount Minus PrimaryInsurance Payment
    for i in range(0,len(Secondary_allowed_amt)):
        if(data1["S_Allowed_Amt"][i]>data1["Primary_paid"][i]):
                data1["Secondary_paid"][i] = data1["S_Allowed_Amt"][i] - data1["Primary_paid"][i]
        else:
            data1["Secondary_paid"][i] = 0
    data1["OOP"] = data1["Billed_Amt"]-data1["Primary_paid"]-data1["Secondary_paid"]
# Out:
# <ipython-input-30-c3299a272d58>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["Secondary_paid"][i] = data1["S_Allowed_Amt"][i] - data1["Primary_paid"][i]
# <ipython-input-30-c3299a272d58>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["Secondary_paid"][i] = 0

# %%
data1
# Out:
#         Claim ID                              Primary  \
# 0     1109820231                     Dean Health Plan
# 1     1031142215                  Vantage Health Plan
# 2     1811391063                               Quartz
# 3     1510918907         Ambetter from Buckeye Health
# 4     1679947328                  Aspirus Health Plan
# ...          ...                                  ...
# 9995  1360332344         Ambetter from Buckeye Health
# 9996  1435232368                               Quartz
# 9997  1455330290  Health First Commercial Plans, Inc.
# 9998  1770493708                    Bright HealthCare
# 9999  1839120188               FirstCare Health Plans
#
#                                           Secondary  \
# 0                      Ambetter from Buckeye Health
# 1     Highmark Blue Cross Blue Shield West Virginia
# 2                      Ambetter from Buckeye Health
# 3                                             AvMed
# ...

# %%
data1["TPL"]=0
for i in range(0,len(deduc)):
    if (data1["Primary"][i]=="Medicare" and data1["Secondary"][i]=="Medicaid"):
        data1["TPL"][i] ="0"
    else:
        data1["TPL"][i]="1"
# Out:
# <ipython-input-32-79b6b26b3042>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["TPL"][i]="1"
# <ipython-input-32-79b6b26b3042>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["TPL"][i] ="0"

# %%
data1
# Out:
#         Claim ID                              Primary  \
# 0     1109820231                     Dean Health Plan
# 1     1031142215                  Vantage Health Plan
# 2     1811391063                               Quartz
# 3     1510918907         Ambetter from Buckeye Health
# 4     1679947328                  Aspirus Health Plan
# ...          ...                                  ...
# 9995  1360332344         Ambetter from Buckeye Health
# 9996  1435232368                               Quartz
# 9997  1455330290  Health First Commercial Plans, Inc.
# 9998  1770493708                    Bright HealthCare
# 9999  1839120188               FirstCare Health Plans
#
#                                           Secondary  \
# 0                      Ambetter from Buckeye Health
# 1     Highmark Blue Cross Blue Shield West Virginia
# 2                      Ambetter from Buckeye Health
# 3                                             AvMed
# ...

# %%
data1["Total_Coverage"] = data1["Primary_paid"] + data1["Secondary_paid"]

# %%
data1
# Out:
#         Claim ID                              Primary  \
# 0     1109820231                     Dean Health Plan
# 1     1031142215                  Vantage Health Plan
# 2     1811391063                               Quartz
# 3     1510918907         Ambetter from Buckeye Health
# 4     1679947328                  Aspirus Health Plan
# ...          ...                                  ...
# 9995  1360332344         Ambetter from Buckeye Health
# 9996  1435232368                               Quartz
# 9997  1455330290  Health First Commercial Plans, Inc.
# 9998  1770493708                    Bright HealthCare
# 9999  1839120188               FirstCare Health Plans
#
#                                           Secondary  \
# 0                      Ambetter from Buckeye Health
# 1     Highmark Blue Cross Blue Shield West Virginia
# 2                      Ambetter from Buckeye Health
# 3                                             AvMed
# ...

# %%
train_data = data1.drop(["Claim ID","Primary","Secondary","Plan_Type","CoInsurance","OOP","Primary_paid","Secondary_paid","TPL"], axis=1)

# %%
train_data
# Out:
#                        Claim Type  Billed_Amt  P_Allowed_Amt  Deductible  \
# 0          Medicare Part A Claims        4101           2429          36
# 1     Professional Service Claims        4812           1336          62
# 2           Long Term Care Claims        4077           2404          30
# 3       Hospital Inpatient Claims        4922           1844          30
# 4           RHC, FQHC, IHC Claims        5581           1002          59
# ...                           ...         ...            ...         ...
# 9995       Medicare Part A Claims        4478           1710          59
# 9996        Long Term Care Claims        5422           1086          48
# 9997  Professional Service Claims        4417           1604          64
# 9998  Professional Service Claims        4758           2933          63
# 9999        RHC, FQHC, IHC Claims        5590           1465          51
#
#       Copay  S_Allowed_Amt  CoInsurance_Amt  Total_Coverage
# ...

# %%
from sklearn import preprocessing
 
label_encoder = preprocessing.LabelEncoder()
train_data['Claim Type']= label_encoder.fit_transform(train_data['Claim Type'])
train_data['Claim Type'].unique()
# Out:
# array([2, 5, 1, 0, 6, 3, 4])

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler    
X = train_data.drop("Total_Coverage", axis=1)
y = train_data["Total_Coverage"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
# Out:
# (7000, 7)
# (3000, 7)
# (7000,)

# %%
data1.to_excel("P:/COB.xlsx")

# %%
data1
# Out:
#         Claim ID                              Primary  \
# 0     1109820231                     Dean Health Plan
# 1     1031142215                  Vantage Health Plan
# 2     1811391063                               Quartz
# 3     1510918907         Ambetter from Buckeye Health
# 4     1679947328                  Aspirus Health Plan
# ...          ...                                  ...
# 9995  1360332344         Ambetter from Buckeye Health
# 9996  1435232368                               Quartz
# 9997  1455330290  Health First Commercial Plans, Inc.
# 9998  1770493708                    Bright HealthCare
# 9999  1839120188               FirstCare Health Plans
#
#                                           Secondary  \
# 0                      Ambetter from Buckeye Health
# 1     Highmark Blue Cross Blue Shield West Virginia
# 2                      Ambetter from Buckeye Health
# 3                                             AvMed
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
import statsmodels.formula.api as sm
regressor = RandomForestRegressor(n_estimators=20, random_state=0)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('R2 Score:', metrics.r2_score(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 13.42784833333334
# R2 Score: 0.9986384847148104
# Mean Squared Error: 1188.4601605333337
# Root Mean Squared Error: 34.47405053853309

# %%
import shap
explainer = shap.TreeExplainer(regressor)
shap_values = explainer.shap_values(X_test)

# %%
shap.summary_plot(shap_values, X_test, plot_type="bar",)
shap.summary_plot(shap_values, X_test)

# %%
df=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
df
# Out:
#        Actual  Predicted
# 9394  3558.70  3558.6425
# 898   1529.25  1528.7175
# 2398  3720.00  3719.1900
# 5906  2278.95  2279.1375
# 2343  3106.50  3106.9700
# ...       ...        ...
# 4004  2411.00  2408.5500
# 7375  1153.50  1153.6250
# 9307  1104.00  1104.0000
# 8394  3337.80  3337.2025
# 5233  1243.20  1160.2500
#
# [3000 rows x 2 columns]

# %%
#Calculate the absolute errors
errors = abs(y_pred - y_test)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')

# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / y_test)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Mean Absolute Error: 13.43 degrees.
# Accuracy: 98.98 %.
